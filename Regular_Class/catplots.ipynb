# %%
import pandas as pd
df=pd.read_csv("survey lung cancer.csv")
df
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
df1=df['GENDER']='Gender'

# %%
df2=pd.DataFrame(data=pd.read_csv("survey lung cancer.csv",index=[['Gender','Age','Smoking','Yellow_Finger','Anxiety','Peer_Pressure','ChronicDisease','Fatigue','Allergy','Wheezing','Alcohol_Consuming','Coughing','Shortness_of_breath','swallowing_difficulty','ChestPain','Lung_Cancer']]))
df2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\maadi\Python programming\catplots.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/maadi/Python%20programming/catplots.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df2=pd.DataFrame(data=pd.read_csv("survey lung cancer.csv",index=[['Gender','Age','Smoking','Yellow_Finger','Anxiety','Peer_Pressure','ChronicDisease','Fatigue','Allergy','Wheezing','Alcohol_Consuming','Coughing','Shortness_of_breath','swallowing_difficulty','ChestPain','Lung_Cancer']]))
#       <a href='vscode-notebook-cell:/c%3A/Users/maadi/Python%20programming/catplots.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> df2
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %% [markdown]
# write a python program with the following specification there will be a function named create dataset which will take a dictionary,filename,number of rows as arguements. the dictionary is having the following structure{
#     "colunmname":[domain of values]
# }
# your function will select random values for each of the domains  and create a row for you .
# the number of rows that has to be crated is a parameter that has been taken. save the file with the number of rows.
# load this dataset using pandas and display basic information

# %%
import random

# Creating dictionary

dict = {
    'Name' : ['Repiece','Devu','Kundimwon','Shaddimwon','Kusu','Jof'] ,
    'Age' : ['23','22','21','20','19','25'] ,
    'Year' : ['2000','2002','2003','2016','2017','2019'] ,
    'Year of Study' : ['2','4','5','4','1','6'] ,
    'Income' : ['0'] ,
    'Place' : ['Kerala']
}

# Creating a function CreateDataset

def createDataset(filename,n):

    file = open(filename,'a+')
    file.write('Name' '\t' + 'Age' '\t' + 'Year' '\t' + 'Year of study' '\t' + 'Income' '\t' + 'Place' '\n')
    file.close()

    file = open(filename,'a+' )
    for i in range(n+1):
        file.write(random.choice(dict['Name']) + '\t' + random.choice(dict['Age']) + '\t' + random.choice(dict['Year']) + '\t' + random.choice(dict['Year of Study']) + '\t' + random.choice(dict['Income']) + '\t' + random.choice(dict['Place']) + '\n')
    file.close()

createDataset('Unda.csv' , 20)

# %%
import pandas as pd

df = pd.read_csv('Unda.csv', delimiter = '\t')
df
# Out:
#          Name  Age  Year  Year of study  Income   Place
# 0        Kusu   19  2002              6       0  Kerala
# 1   Kundimwon   25  2016              6       0  Kerala
# 2         Jof   19  2017              4       0  Kerala
# 3        Devu   19  2002              6       0  Kerala
# 4        Devu   20  2017              6       0  Kerala
# 5        Kusu   19  2000              6       0  Kerala
# 6     Repiece   20  2017              4       0  Kerala
# 7     Repiece   19  2017              6       0  Kerala
# 8     Repiece   25  2016              4       0  Kerala
# 9        Devu   21  2002              2       0  Kerala
# 10        Jof   19  2019              1       0  Kerala
# 11    Repiece   25  2002              4       0  Kerala
# 12       Devu   19  2017              5       0  Kerala
# 13        Jof   19  2017              2       0  Kerala
# 14       Devu   25  2000              4       0  Kerala
# 15       Devu   19  2000              2       0  Kerala
# ...

# %%
print(df.head(5))
# Out:
#         Name  Age  Year  Year of study  Income   Place
# 0       Kusu   19  2002              6       0  Kerala
# 1  Kundimwon   25  2016              6       0  Kerala
# 2        Jof   19  2017              4       0  Kerala
# 3       Devu   19  2002              6       0  Kerala
# 4       Devu   20  2017              6       0  Kerala

# %%
print(df.tail(5))
# Out:
#          Name  Age  Year  Year of study  Income   Place
# 16  Kundimwon   23  2002              6       0  Kerala
# 17       Devu   21  2003              4       0  Kerala
# 18  Kundimwon   23  2003              2       0  Kerala
# 19       Kusu   25  2017              4       0  Kerala
# 20       Kusu   22  2002              6       0  Kerala

# %%
print(df.shape)
# Out:
# (21, 6)
