# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\maadi\appdata\local\programs\python\python311\lib\site-packages (2.1.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.23.2 in c:\users\maadi\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maadi\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maadi\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\maadi\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\maadi\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# %%
set = pd.read_csv("spotify-2023.txt", delimiter='\t')
set.head(10)
# Out:
#                             track_name              artist(s)_name  \
# 0  Seven (feat. Latto) (Explicit Ver.)            Latto, Jung Kook
# 1                                 LALA                 Myke Towers
# 2                              vampire              Olivia Rodrigo
# 3                         Cruel Summer                Taylor Swift
# 4                       WHERE SHE GOES                   Bad Bunny
# 5                             Sprinter           Dave, Central Cee
# 6                      Ella Baila Sola  Eslabon Armado, Peso Pluma
# 7                             Columbia                     Quevedo
# 8                             fukumean                       Gunna
# 9                      La Bebe - Remix       Peso Pluma, Yng Lvcas
#
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# 2             1           2023               6            30
# 3             1           2019               8            23
# 4             1           2023               5            18
# 5             2           2023               6             1
# 6             2           2023               3            16
# 7             1           2023               7             7
# 8             1           2023               5            15
# 9             2           2023               3            17
#
#    in_spotify_playlists  in_spotify_charts      streams  in_apple_playlists  \
# 0                   553                147  141381703.0                43.0
# 1                  1474                 48  133716286.0                48.0
# 2                  1397                113  140003974.0                94.0
# 3                  7858                100  800840817.0               116.0
# 4                  3133                 50  303236322.0                84.0
# 5                  2186                 91  183706234.0                67.0
# 6                  3090                 50  725980112.0                34.0
# 7                   714                 43   58149378.0                25.0
# 8                  1096                 83   95217315.0                60.0
# 9                  2953                 44  553634067.0                49.0
#
#    ...    bpm key   mode danceability_%  valence_% energy_% acousticness_%  \
# 0  ...  125.0   B  Major           80.0       89.0     83.0           31.0
# 1  ...   92.0  C#  Major           71.0       61.0     74.0            7.0
# 2  ...  138.0   F  Major           51.0       32.0     53.0           17.0
# 3  ...  170.0   A  Major           55.0       58.0     72.0           11.0
# 4  ...  144.0   A  Minor           65.0       23.0     80.0           14.0
# 5  ...  141.0  C#  Major           92.0       66.0     58.0           19.0
# 6  ...  148.0   F  Minor           67.0       83.0     76.0           48.0
# 7  ...  100.0   F  Major           67.0       26.0     71.0           37.0
# 8  ...  130.0  C#  Minor           85.0       22.0     62.0           12.0
# 9  ...  170.0   D  Minor           81.0       56.0     48.0           21.0
#
#    instrumentalness_%  liveness_%  speechiness_%
# 0                 0.0         8.0            4.0
# 1                 0.0        10.0            4.0
# 2                 0.0        31.0            6.0
# 3                 0.0        11.0           15.0
# 4                63.0        11.0            6.0
# 5                 0.0         8.0           24.0
# 6                 0.0         8.0            3.0
# 7                 0.0        11.0            4.0
# 8                 0.0        28.0            9.0
# 9                 0.0         8.0           33.0
#
# [10 rows x 24 columns]

# %%
class pandu():

    def _init_(self):
        self.filename = ""
        self.filecontent = []
        self.columns = ""

    def read_csv(self,filename):
        self.filename = filename
        try:
            with open(filename, 'r+') as file:
                self.columns = file.readline()
                self.filecontent = file.readlines()
        except:
            print("File not found.")

    def head(self,num_of_rows):
        for i in range(0,num_of_rows):
            print(self.filecontent[i].strip())

    def tail(self,num_of_rows):
            start = len(self.filecontent)-(num_of_rows+1)
            end = len(self.filecontent) -1
            for i in range(start,end):
                print(self.filecontent[i].strip())

x = pandu()
x.read_csv("spotify-2023.txt")
x.head(5)
x.tail(5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\maadi\Python programming\pandas.ipynb Cell 4 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/maadi/Python%20programming/pandas.ipynb#W3sZmlsZQ%3D%3D?line=26'>27</a> x = pandu()
#      <a href='vscode-notebook-cell:/c%3A/Users/maadi/Python%20programming/pandas.ipynb#W3sZmlsZQ%3D%3D?line=27'>28</a> x.read_csv("spotify-2023.txt")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/maadi/Python%20programming/pandas.ipynb#W3sZmlsZQ%3D%3D?line=28'>29</a> x.head(5)
#      <a href='vscode-notebook-cell:/c%3A/Users/maadi/Python%20programming/pandas.ipynb#W3sZmlsZQ%3D%3D?line=29'>30</a> x.tail(5)
#
# c:\Users\maadi\Python programming\pandas.ipynb Cell 4 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/maadi/Python%20programming/pandas.ipynb#W3sZmlsZQ%3D%3D?line=16'>17</a> def head(self,num_of_rows):
#      <a href='vscode-notebook-cell:/c%3A/Users/maadi/Python%20programming/pandas.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a>     for i in range(0,num_of_rows):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/maadi/Python%20programming/pandas.ipynb#W3sZmlsZQ%3D%3D?line=18'>19</a>         print(self.filecontent[i].strip())
#
# IndexError: list index out of range
